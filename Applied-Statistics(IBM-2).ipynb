# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate binomial data
x = np.random.binomial(n=10, p=0.5, size=10)

# Create a histogram
plt.hist(x, bins=range(12), edgecolor='black', alpha=0.7)
plt.title('Binomial Distribution')
plt.xlabel('Number of Successes')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import numpy as np
info=np.array(['P','a','n','d','a','s'])
a=pd.Series(info)
print(a)
# Out:
# 0    P
# 1    a
# 2    n
# 3    d
# 4    a
# 5    s
# dtype: object

# %%
import pandas as pd
#a list of Strings
x=['Python','Pandas']
#Calling dataframe constructor on list
df=pd.DataFrame(x)
print(df)
# Out:
#         0
# 0  Python
# 1  Pandas

# %%
import pandas as pd
import numpy as np
a=pd.Series(['Java','C','C++',np.nan])
a.map({'Java':'Core'})
# Out:
# 0    Core
# 1     NaN
# 2     NaN
# 3     NaN
# dtype: object

# %%
import pandas as pd
import numpy as np
a=pd.Series(['Java','C','C++',np.nan])
a.map({'Java':'Core'})
a.map('I like {}'.format,na_action='ignore')
# Out:
# 0    I like Java
# 1       I like C
# 2     I like C++
# 3            NaN
# dtype: object

# %%
s=pd.Series(["a","b","c"],name="vals")
s.to_frame()
# Out:
#   vals
# 0    a
# 1    b
# 2    c

# %%
import pandas as pd
import matplotlib.pyplot as plt
emp=['parker','John','Smith','William']
id=[102,107,109,114]
emp_series=pd.Series(emp)
id_series=pd.Series(id)
frame={'Emp':emp_series,'ID':id_series}
result=pd.DataFrame(frame)
print(result)
# Out:
#        Emp   ID
# 0   parker  102
# 1     John  107
# 2    Smith  109
# 3  William  114

# %%
import pandas as pd
info={'ID':[101,102,103],'Department':['B.Sc','B.Tech','M.Tech']}
df=pd.DataFrame(info)
print(df)
# Out:
#     ID Department
# 0  101       B.Sc
# 1  102     B.Tech
# 2  103     M.Tech

# %%
import pandas as pd
info={'one':pd.Series([1,2,3,4,5,6],index=['a','b','c','d','e','f']),'two':pd.Series([1,2,3,4,5,6,7,8],index=['a','b','c','d','e','f','g','h'])}
d1=pd.DataFrame(info)
print(d1)
# Out:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  4.0    4
# e  5.0    5
# f  6.0    6
# g  NaN    7
# h  NaN    8

# %%
import pandas as pd
info={'one':pd.Series([1,2,3,4,5,6],),'two':pd.Series([1,2,3,4,5,6,7,8],)}
d1=pd.DataFrame(info)
print(d1)
# Out:
#    one  two
# 0  1.0    1
# 1  2.0    2
# 2  3.0    3
# 3  4.0    4
# 4  5.0    5
# 5  6.0    6
# 6  NaN    7
# 7  NaN    8

# %%
#Assesment-1
#Creating a dictionary
import pandas as pd
a={'name':pd.Series(['John','Smith','Marrie']),'age':([15,18,23]),'City':(['XXX','YYY','ZZZ'])}
#Converting this into dataframe
df=pd.DataFrame(a)
print(df)
# Out:
#      name  age City
# 0    John   15  XXX
# 1   Smith   18  YYY
# 2  Marrie   23  ZZZ

# %%
#Assesment-1
#Creating a list of list
import pandas as pd
x=[['X',3,2.0],['Y',5,3.0],['Z',9,5.3]]
#Converting it into dataframe
w=pd.DataFrame(x)
print(w)
# Out:
#    0  1    2
# 0  X  3  2.0
# 1  Y  5  3.0
# 2  Z  9  5.3

# %%
import pandas as pd
info={'one':pd.Series([1,2],index=['a','b']),'two':pd.Series([1,2,3],index=['a','b','c'])}
df=pd.DataFrame(info)
print("The DataFrame:")
print(df)
print("Delete the first column:")
del df['one']
print(df)
print("Delete the another column:")
df.pop('two')
print(df)
# Out:
# The DataFrame:
#    one  two
# a  1.0    1
# b  2.0    2
# c  NaN    3
# Delete the first column:
#    two
# a    1
# b    2
# c    3
# Delete the another column:
# Empty DataFrame
# Columns: []
# Index: [a, b, c]

# %%
import pandas as pd
info={'one':pd.Series([1,2,3,4,5],index=['a','b','c','d','e']),'two':pd.Series([1,2,3,4,5,6],index=['a','b','c','d','e','f'])}
df=pd.DataFrame(info)
print(df.loc['b'])
# Out:
# one    2.0
# two    2.0
# Name: b, dtype: float64

# %%
d=pd.DataFrame([[7,8],[9,10]],columns=['x','y'])
d2=pd.DataFrame([[11,12],[13,14]],columns=['x','y'])
df_combined= pd.concat([d, d2], ignore_index=True)
print("Combined DataFrame using concat():\n", df_combined)
# Out:
# Combined DataFrame using concat():
#      x   y
# 0   7   8
# 1   9  10
# 2  11  12
# 3  13  14

# %%
#Assesment-2
import pandas as pd
# Create a dictionary with student details
students = {
    "name": [
        "Alice Johnson", "Bob Smith", "Charlie Brown", "Diana Prince",
        "Ethan Hunt", "Fiona Gallagher", "George Smith", "Hannah Baker"
    ],
    "id": [
        "S001", "S002", "S003", "S004",
        "S005", "S006", "S007", "S008"
    ],
    "department": [
        "Computer Science", "Mathematics", "Physics", "Chemistry",
        "Engineering", "Biology", "History", "Literature"
    ],
    "grade": [
        "A", "B", "A-", "B+",
        "B-", "A", "C+", "A+"
    ]
}

# Convert dictionary into a DataFrame
df = pd.DataFrame(students)

# 1. Retrieve students using department names
def get_students_by_department(department):
    return df.loc[df['department'] == department]

# 2. Retrieve the iloc for 2
rows = df.iloc[2]  
print(rows)

# 3. Retrieve the IDs of the students
 # Using loc to get the 'id' column
student_ids = df.loc[:, 'id'].tolist()  
print("\nStudent IDs:\n", student_ids)
# Out:
# name          Charlie Brown
# id                     S003
# department          Physics
# grade                    A-
# Name: 2, dtype: object
#
# Student IDs:
#  ['S001', 'S002', 'S003', 'S004', 'S005', 'S006', 'S007', 'S008']

# %%
import pandas as pd
a_info = pd.DataFrame([[4, 5], [6, 7]], columns=['x', 'y'])
b_info = pd.DataFrame([[8, 9], [10, 11]], columns=['x', 'y'])
d = pd.concat([a_info, b_info], ignore_index=True)
d = d.drop(index=0)
print(d)
# Out:
#     x   y
# 1   6   7
# 2   8   9
# 3  10  11

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\sahus\\OneDrive\\Desktop\\Lungcancer.csv")
print(df)
# Out:
#      GENDER  AGE SMOKING YELLOW_FINGERS ANXIETY PEER_PRESSURE CHRONIC_DISEASE  \
# 0         M   65     Yes            Yes     Yes            No              No
# 1         F   55     Yes             No      No           Yes             Yes
# 2         F   78      No             No     Yes           Yes             Yes
# 3         M   60      No            Yes     Yes           Yes              No
# 4         F   80     Yes            Yes      No           Yes             Yes
# ...     ...  ...     ...            ...     ...           ...             ...
# 2995      F   71      No            Yes     Yes            No              No
# 2996      F   75     Yes             No     Yes           Yes             Yes
# 2997      F   62      No             No      No           Yes              No
# 2998      M   30     Yes            Yes      No            No              No
# 2999      M   40     Yes             No      No           Yes             Yes
#
# ...

# %%
import pandas as pd
info={'one':pd.Series([1,2,3,4,5,],index=['a','b','c','d','e']),'two':pd.Series([1,2,3,4,5,6],index=['a','b','c','d','e','f'])}
df=pd.DataFrame(info)
#Add new column to an existing DataFrame object
print("Add new column by passing series")
df['three']=pd.Series([20,40,60],index=['a','b','c'])
print(df)
# Out:
# Add new column by passing series
#    one  two  three
# a  1.0    1   20.0
# b  2.0    2   40.0
# c  3.0    3   60.0
# d  4.0    4    NaN
# e  5.0    5    NaN
# f  NaN    6    NaN

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\sahus\\OneDrive\\Desktop\\Lungcancer.csv")
df.head(6)
# Out:
#   GENDER  AGE SMOKING YELLOW_FINGERS ANXIETY PEER_PRESSURE CHRONIC_DISEASE  \
# 0      M   65     Yes            Yes     Yes            No              No
# 1      F   55     Yes             No      No           Yes             Yes
# 2      F   78      No             No     Yes           Yes             Yes
# 3      M   60      No            Yes     Yes           Yes              No
# 4      F   80     Yes            Yes      No           Yes             Yes
# 5      F   58     Yes            Yes     Yes            No              No
#
#   FATIGUE ALLERGY WHEEZING ALCOHOL_CONSUMING COUGHING SHORTNESS_OF_BREATH  \
# 0     Yes      No       No                No       No                  No
# 1      No      No       No               Yes      Yes                 Yes
# 2      No     Yes       No               Yes      Yes                  No
# 3     Yes      No      Yes               Yes       No                 Yes
# ...

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\sahus\\OneDrive\\Desktop\\Lungcancer.csv")
df.tail(7)
# Out:
#      GENDER  AGE SMOKING YELLOW_FINGERS ANXIETY PEER_PRESSURE CHRONIC_DISEASE  \
# 2993      F   80      No            Yes     Yes           Yes             Yes
# 2994      F   45     Yes             No     Yes            No             Yes
# 2995      F   71      No            Yes     Yes            No              No
# 2996      F   75     Yes             No     Yes           Yes             Yes
# 2997      F   62      No             No      No           Yes              No
# 2998      M   30     Yes            Yes      No            No              No
# 2999      M   40     Yes             No      No           Yes             Yes
#
#      FATIGUE ALLERGY WHEEZING ALCOHOL_CONSUMING COUGHING SHORTNESS_OF_BREATH  \
# 2993      No      No      Yes                No       No                 Yes
# 2994      No     Yes       No                No      Yes                  No
# 2995     Yes     Yes      Yes               Yes       No                 Yes
# ...

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\sahus\\OneDrive\\Desktop\\Lungcancer.csv")
df.shape
# Out:
# (3000, 16)

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\sahus\\OneDrive\\Desktop\\Lungcancer.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 3000 non-null   object
#  1   AGE                    3000 non-null   int64
#  2   SMOKING                3000 non-null   object
#  3   YELLOW_FINGERS         3000 non-null   object
#  4   ANXIETY                3000 non-null   object
#  5   PEER_PRESSURE          3000 non-null   object
#  6   CHRONIC_DISEASE        3000 non-null   object
#  7   FATIGUE                3000 non-null   object
#  8   ALLERGY                3000 non-null   object
#  9   WHEEZING               3000 non-null   object
#  10  ALCOHOL_CONSUMING      3000 non-null   object
#  11  COUGHING               3000 non-null   object
#  12  SHORTNESS_OF_BREATH    3000 non-null   object
#  13  SWALLOWING_DIFFICULTY  3000 non-null   object
# ...

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\sahus\\OneDrive\\Desktop\\Lungcancer.csv")
s.value_counts(dropna=False)
# Out:
# vals
# a    1
# b    1
# c    1
# Name: count, dtype: int64

# %%
df.apply(pd.Series.value_counts)
# Out:
#      GENDER   AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# M    1514.0   NaN      NaN             NaN      NaN            NaN
# F    1486.0   NaN      NaN             NaN      NaN            NaN
# 54      NaN  73.0      NaN             NaN      NaN            NaN
# 67      NaN  71.0      NaN             NaN      NaN            NaN
# 75      NaN  71.0      NaN             NaN      NaN            NaN
# 47      NaN  70.0      NaN             NaN      NaN            NaN
# 69      NaN  70.0      NaN             NaN      NaN            NaN
# 78      NaN  69.0      NaN             NaN      NaN            NaN
# 55      NaN  69.0      NaN             NaN      NaN            NaN
# 79      NaN  68.0      NaN             NaN      NaN            NaN
# 53      NaN  66.0      NaN             NaN      NaN            NaN
# 32      NaN  66.0      NaN             NaN      NaN            NaN
# 39      NaN  65.0      NaN             NaN      NaN            NaN
# ...

# %%
#Data Cleaning
import pandas as pd 
df=pd.read_csv("C:\\Users\\sahus\\OneDrive\\Desktop\\Lungcancer.csv")
pd.isnull
# Out:
# <function pandas.core.dtypes.missing.isna(obj: 'object') -> 'bool | npt.NDArray[np.bool_] | NDFrame'>

# %%
import pandas as pd 
df=pd.read_csv("C:\\Users\\sahus\\OneDrive\\Desktop\\Lungcancer.csv")
pd.notnull
# Out:
# <function pandas.core.dtypes.missing.notna(obj: 'object') -> 'bool | npt.NDArray[np.bool_] | NDFrame'>

# %%
import pandas as pd 
df=pd.read_csv("C:\\Users\\sahus\\OneDrive\\Desktop\\Lungcancer.csv")
df.dropna()
# Out:
#      GENDER  AGE SMOKING YELLOW_FINGERS ANXIETY PEER_PRESSURE CHRONIC_DISEASE  \
# 0         M   65     Yes            Yes     Yes            No              No
# 1         F   55     Yes             No      No           Yes             Yes
# 2         F   78      No             No     Yes           Yes             Yes
# 3         M   60      No            Yes     Yes           Yes              No
# 4         F   80     Yes            Yes      No           Yes             Yes
# ...     ...  ...     ...            ...     ...           ...             ...
# 2995      F   71      No            Yes     Yes            No              No
# 2996      F   75     Yes             No     Yes           Yes             Yes
# 2997      F   62      No             No      No           Yes              No
# 2998      M   30     Yes            Yes      No            No              No
# 2999      M   40     Yes             No      No           Yes             Yes
#
# ...

# %%
import pandas as pd 
df=pd.read_csv("C:\\Users\\sahus\\OneDrive\\Desktop\\Lungcancer.csv")
df.dropna(axis=1)
# Out:
#      GENDER  AGE SMOKING YELLOW_FINGERS ANXIETY PEER_PRESSURE CHRONIC_DISEASE  \
# 0         M   65     Yes            Yes     Yes            No              No
# 1         F   55     Yes             No      No           Yes             Yes
# 2         F   78      No             No     Yes           Yes             Yes
# 3         M   60      No            Yes     Yes           Yes              No
# 4         F   80     Yes            Yes      No           Yes             Yes
# ...     ...  ...     ...            ...     ...           ...             ...
# 2995      F   71      No            Yes     Yes            No              No
# 2996      F   75     Yes             No     Yes           Yes             Yes
# 2997      F   62      No             No      No           Yes              No
# 2998      M   30     Yes            Yes      No            No              No
# 2999      M   40     Yes             No      No           Yes             Yes
#
# ...
